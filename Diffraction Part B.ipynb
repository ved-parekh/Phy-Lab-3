# %% [markdown]
# #### Part B, Surface Tension, Sheet 5 Data, units of length in cm

# %%
import matplotlib.pyplot as plt 
import numpy as np

#lnw2= [4.49980967,4.605170186,4.700480366,4.787491743,4.86753445] #4.941642423, 5.010635294,5.075173815,5.135798437,5.192956851]

lnw2= [6.219903701,6.337686737,6.443047252,6.538357432,6.625368809,6.705411517] #6.779519489,6.84851236,6.913050882,6.973675503,7.030833917]

lnk2= [8.346460345, 8.420533352,8.489491171,8.553994551,8.614583943,8.67170704] # 8.67170704,8.67170704,8.614583943,8.67170704,8.67170704]


plt.scatter(lnk2,lnw2)



a2,b2 = np.polyfit(lnk2, lnw2, 1)


bestfitline= [a2*x + b2 for x in lnk2] 

plt.plot(lnk2, bestfitline , linestyle='dashed',  color='red', label='Best fit line ')
plt.xlabel('ln(k)')
plt.ylabel('ln(w)')
plt.legend()
print(f"slope: {a2}")
print(f"intercept: {b2}")

#lnw2= [6.337686737,6.443047252,6.538357432,6.625368809,6.705411517,6.779519489,6.84851236,6.913050882,6.973675503,7.030833917]
# Out:
# slope: 1.4913375706567862
# intercept: -6.222126331954374
